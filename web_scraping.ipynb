# %%
#Import these libraries
import requests
from bs4 import BeautifulSoup

# %%
#URL Extraction
url = "https://boston.craigslist.org/search/sof"

# %%
response = requests.get(url)

# %%
response #200 means Great, your internet connection works
# Out:
# <Response [200]>

# %%
#Now we need to extract the source code of the web page
data = response.text

# %%
data
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>boston software/qa/dba/etc  jobs - craigslist</title>\n    <script type="application/ld+json" id="ld_breadcrumb_data" >\n    {"@context":"https://schema.org","itemListElement":[{"item":{"name":"boston.craigslist.org","@id":"https://boston.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"jobs","@id":"https://boston.craigslist.org/d/jobs/search/jjj"},"position":2,"@type":"ListItem"},{"item":{"name":"software","@id":"https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}\n</script>\n\n\n    <meta name="description" content="">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n        <link rel="canonical" href="https://boston.craigslist.org/d/software-qa-dba-etc/search/sof">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org
# ...

# %%
#Pass the code to BS4 
soup= BeautifulSoup(data, "html.parser")

# %%
tags = soup.find_all('a')

# %%
tags #Test with web page
# Out:
# [<a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#          Android
#      </a>,
#  <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#          iOS
#      </a>,
#  <a class="header-logo" href="/" name="logoLink">CL</a>,
#  <a href="/">boston</a>,
#  <a href="https://post.craigslist.org/c/bos">post</a>,
#  <a href="https://accounts.craigslist.org/login/home">account</a>,
#  <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>,
#  <a class="to-banish-page-link" href="#">
#  <span aria-hidden="true" class="icon icon-trash red"></span>
#  <span class="banished_count">0</span>
#  <span class="discards-label"> hidden</span>
#  </a>,
#  <a class="header-logo" href="/">CL</a>,
# ...

# %%
for tag in tags:
    print(tag.get('href'))
# Out:
# https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile
# https://apps.apple.com/us/app/craigslist/id1336642410
# /
# /
# https://post.craigslist.org/c/bos
# https://accounts.craigslist.org/login/home
# #
# #
# /
# https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fboston%2Ecraigslist%2Eorg%2Fd%2Fsoftware%2Dqa%2Ddba%2Detc%2Fsearch%2Fsof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof?sort=date&
#
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
#
# https://boston.craigslist.org/gbs/sof/d/cambridge-back-end-developer/7313681646.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-back-end-developer/7313681646.html
# #
# https://boston.craigslist.org/gbs/sof/d/cambridge-full-stack-developer/7313678816.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-full-stack-developer/7313678816.html
# #
# ...

# %%
titles = soup.find_all("a", {"class": "result-title"})

# %%
for title in titles:
    print(title.text)
# Out:
# Back-End Developer
# Full Stack Developer
# Software Engineer
# React/React Native Frontend Developer (Remote, Contract)
# Contractor Backend Developer
# Software Engineer
# Data Science Fellowship
# Product Management Fellowship
# Software Engineering Fellowship
# Software Engineer
# Sr. Software Engineer
# Sr. Software Engineer
# Entry Level - Software Developer
# Software Engineer
# Best In-Demand IT Skills & Job Training Program
# Earn $$$ from home - Pixel phone tester
# print On-site VR Device Testing
# Data Science Fellowship
# Product Management Fellowship
# Software Engineering Fellowship
# Certified Encompass Developer/Programmer
# Software Engineer
# Xamarine Software Developer
# Software Engineer
# Software Engineer
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# database tutor
# PowerBuilder Programmer/Analyst Position
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# ...

# %%
adresses  = soup.find_all("span", {"class": "result-hood"})

# %%
for address in adresses:
    print(address.text)
# Out:
#  (Cambridge)
#  (Cambridge)
#  (Remote)
#  (Remote)
#  (Remote)
#  (boston: northwest/merrimack)
#  (boston: northwest/merrimack)
#  (Remote)
#  (Framingham)
#  (Boston)
#  (Remote)
#  (Newton Highlands)
#  (Remote)
#  (Remote)
#  (FRAMINGHAM)
#  (Billerica)
#  (Medford, MA)
#  (Medford, MA)
#  (Medford)
#  (Remote)
#  (Remote)
#  (boston: boston/cambridge/brookline)
#  (Rhode Island)
#  (Newton, MA)
#  ((Local or Remote USA ONLY))
#  (Boston, MA)

# %%
jobs = soup.find_all('div',{'class':'result-info'})

# %%
#Extract all the jobs with their title, location, date and link.
for job in jobs:
    title = job.find('a', {'class': 'result-title'}).text
    location_tag = job.find('span', {'class': 'result-hood'})
    location = location_tag.text[2:-1] if location_tag else "N/A"
    date = job.find('time', {'class': 'result-date'}).text
    link = job.find('a', {'class': 'result-title'}).get('href')
    #Another page
    job_response = requests.get(link)
    job_data = job_response.text
    job_soup = BeautifulSoup(job_data, 'html.parser')
    job_description = job_soup.find('section', {'id': 'postingbody'}).text
    job_attributes_tag = job_soup.find('div', {'class': 'attrgroup'})
    job_attributes  = job_attributes_tag.text if job_attributes_tag else "N/A"
    print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink: ', link, '\nJob Description: ', job_description,
          '\nJob Attributes: ', job_attributes,'\n---')
# Out:
# Job Title: Back-End Developer
# Location: Cambridge
# Date: Apr 27
# Link:  https://boston.craigslist.org/gbs/sof/d/cambridge-back-end-developer/7313681646.html
# Job Description:
#
# QR Code Link to This Post
#
#
# Applied Invention is a multi-disciplinary innovation company that partners with corporations to design and build new technologies to help them grow and adapt to rapidly changing environments.  We are a group of experienced technologists that have especially strong skills in building complex systems that incorporate data analytics, artificial intelligence, cloud computing, machine learning, distributed sensors, robotics and data visualization. We work at the speed of a startup, with quality that comes from years of working together as a cohesive team.
#
# ...

# %%
#This example is when you have more than a page and you want to save the file as CSV.
job_no = 0
import pandas as pd
npo_jobs={}

# %%
#Next page
url = "https://boston.craigslist.org/search/npo"



while True:
    
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data,'html.parser')
    jobs = soup.find_all('div',{'class':'result-info'})
    for job in jobs:
        title = job.find('a',{'class':'result-title'}).text
        location_tag = job.find('span',{'class':'result-hood'})
        location = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find('time', {'class': 'result-date'}).text
        link = job.find('a', {'class': 'result-title'}).get('href')
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_description = job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('div',{'class':'attrgroup'})
        job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
        job_no+=1
        npo_jobs[job_no] = [title, location, date, link, job_attributes, job_description]
        
        print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url= 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break

print("Total Jobs:", job_no)
# Out:
# Job Title: Part-Time Dining Site Manager, $15.50/hour (6 hrs/wk & 25 hrs/wk avail
# Location: Waltham, MA
# Date: Apr 27
# Link: https://boston.craigslist.org/gbs/npo/d/waltham-part-time-dining-site-manager/7313269438.html
#  N/A
# Job Description:
#
# QR Code Link to This Post
#
#
# A rewarding Part-Time Dining Site Manager position is available in Springwell's Senior Community Dining Site Program in Watertown!
# Available Positions:
# Watertown: This position offers $15.50/hour for a 25-hour work week. Monday-Friday from 8:30 AM to 1:30 PM.
# QUALIFICATIONS
# Must be organized, efficient, and enjoy working with elders.
# Willing to occasionally cover at other dining sites as needed and be able to lift 25 lbs.
# Willing to attend staff meetings every other month at Springwell in Waltham.
# A reliable car, current driver's license, and safe driving record required.
# Some experience in human services work, preferably with the elderly, preferred.
# ...

# %%
npo_jobs_df = pd.DataFrame.from_dict(npo_jobs, orient = 'index', columns = ['Job Title', 'Location', 'Date', 'Link', 'Job Attributes', 'Job Description'])

npo_jobs_df.head()
# Out:
#                                            Job Title     Location    Date  \
# 1  Part-Time Dining Site Manager, $15.50/hour (6 ...  Waltham, MA  Apr 27
# 2             Part-Time Floating Nutrition Assistant  Waltham, MA  Apr 27
# 3          Part-Time Dining Site Assistant, $15/hour  Waltham, MA  Apr 27
# 4   Part-Time Home Delivered Meals Drivers, $15/hour  Waltham, MA  Apr 27
# 5             Elder Protective Services Investigator  Waltham, MA  Apr 27
#
#                                                 Link Job Attributes  \
# 1  https://boston.craigslist.org/gbs/npo/d/waltha...            N/A
# 2  https://boston.craigslist.org/gbs/npo/d/waltha...            N/A
# 3  https://boston.craigslist.org/gbs/npo/d/waltha...            N/A
# 4  https://boston.craigslist.org/gbs/npo/d/waltha...            N/A
# 5  https://boston.craigslist.org/gbs/npo/d/waltha...            N/A
#
#                                      Job Description
# 1  \n\nQR Code Link to This Post\n\n\nA rewarding...
# ...

# %%
#Save as CSV
npo_jobs_df.to_csv('npo_jobs.csv')
